# %% [raw]
# Esercizio 1: Esaminiamo il dataset: • quanti dati ci sono in totale? • quali sono i metadati? • stampiamo il primo elemento • stampiamo l'ultimo elemento • riusciamo a stampare un elemento a caso? • quali sono gli anni di inserimento presenti? • quante attività ci sono nel quadrato di longitudine 9-10 e latitudine 45-46? • quante attività ci sono nella provincia di Vicenza? • quante enoteche ci sono, e come si chiamano? 3 • quante attività ci sono in Lazio e Abruzzo assieme?

# %%
import pandas as pd
mappa_df = pd.read_csv("~/Downloads/Mappa-dei-pub-circoli-locali-in-Italia.csv", encoding="latin1", sep=";")

# %%
# 1. Quanti dati ci sono in totale?
mappa_df.shape
# Out:
# (2635, 9)

# %%
# 2. Quali sono i metadati?
mappa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2635 entries, 0 to 2634
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Comune                           2635 non-null   object
#  1   Provincia                        2635 non-null   object
#  2   Regione                          2635 non-null   object
#  3   Nome                             2337 non-null   object
#  4   Anno inserimento                 2635 non-null   int64
#  5   Data e ora inserimento           2635 non-null   object
#  6   Identificatore in OpenStreetMap  2635 non-null   int64
#  7   Longitudine                      2635 non-null   float64
#  8   Latitudine                       2635 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 185.4+ KB

# %%
# 3. Primo elemento
mappa_df.head(1)
# Out:
#   Comune Provincia Regione Nome  Anno inserimento Data e ora inserimento  \
# 0  ALTRO     ALTRO   ALTRO  NaN              2011   2011-06-25T23:17:43Z
#
#    Identificatore in OpenStreetMap  Longitudine  Latitudine
# 0                       1339088150    13.733257    45.57583

# %%
# 4. Ultimo elemento
mappa_df.tail(1)
# Out:
#      Comune              Provincia Regione          Nome  Anno inserimento  \
# 2634  TRANI  BARLETTA-ANDRIA-TRANI  Puglia  Well's Fargo              2009
#
#      Data e ora inserimento  Identificatore in OpenStreetMap  Longitudine  \
# 2634   2009-08-10T12:44:03Z                        387223648    16.436765
#
#       Latitudine
# 2634   41.267264

# %%
# 5. Un elemento a caso
mappa_df.sample(1)
# Out:
#        Comune Provincia   Regione Nome  Anno inserimento  \
# 2424  SASSARI   SASSARI  Sardegna  BNO              2014
#
#      Data e ora inserimento  Identificatore in OpenStreetMap  Longitudine  \
# 2424   2014-08-09T06:18:33Z                       3006194733     8.561194
#
#       Latitudine
# 2424   40.727961

# %%
# 6. Anni di inserimento presenti
mappa_df["Anno inserimento"].sort_values(ascending=False).unique()
# Out:
# array([2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007])

# %%
mappa_df
# Out:
#             Comune                       Provincia   Regione             Nome  \
# 0            ALTRO                           ALTRO     ALTRO              NaN
# 1            ALTRO                           ALTRO     ALTRO      Lenny's Pub
# 2            ALTRO                           ALTRO     ALTRO  Murrayfield Pub
# 3            ALTRO                           ALTRO     ALTRO           Snop?e
# 4     ALA DI STURA  CITTA' METROPOLITANA DI TORINO  Piemonte              NaN
# ...            ...                             ...       ...              ...
# 2630      BARLETTA           BARLETTA-ANDRIA-TRANI    Puglia      Santa Croce
# 2631     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia      Auld Dublin
# 2632     BISCEGLIE           BARLETTA-ANDRIA-TRANI    Puglia            Ferus
# 2633         TRANI           BARLETTA-ANDRIA-TRANI    Puglia          Re Artù
# 2634         TRANI           BARLETTA-ANDRIA-TRANI    Puglia     Well's Fargo
#
# ...

# %%
# 7. Attività nel quadrato longitudine 9-10, latitudine 45-46
len(
    mappa_df.loc[
        (mappa_df["Longitudine"] >= 9) & (mappa_df["Longitudine"] <= 10) &
        (mappa_df["Latitudine"] >= 45) & (mappa_df["Latitudine"] <= 46)
])
# Out:
# 306

# %%
# 8. Attività nella provincia di Vicenza
len(mappa_df[mappa_df["Provincia"] == "VICENZA"])
# Out:
# 73

# %%
# 9. Enoteche: quante e come si chiamano
enoteche = mappa_df[mappa_df["Nome"].str.contains("enoteca", case = False, na = False)]
print("Numero enoteche: ", len(enoteche))
print("Nomi enoteche:\n", enoteche["Nome"])
# Out:
# Numero enoteche:  6
# Nomi enoteche:
#  64      Enoteca con Cucina""Tirolin""
# 496                 Concordia Enoteca
# 1003                  Enoteca Umberto
# 1491          Enoteca ""Al Brindisi""
# 1492           Enoteca ""da Massimo""
# 1723         Enoteca Il Violino Rosso
# Name: Nome, dtype: object

# %%
# 10. Attività in Lazio e Abruzzo
len(
    mappa_df.loc[
        (mappa_df["Regione"] == "Lazio") |
        (mappa_df["Regione"] == "Abruzzo")
    ])
# Out:
# 337

# %% [raw]
# Esercizio 2: Il dataset insurance.csv dei beginner_datasets contiene dati su caratteristiche e abitudini delle persone rispetto ai costi individuali per le cure mediche come premio per le assicurazioni sulla salute. • Visualizziamone le dimensioni, un'anteprima, e osserviamo i nomi di colonna; • Quali sono le medie di charges rispetto a region? Ci sono differenze significative? • E rispetto a smoker? E a sex? • Quali sono i descrittori statistici di bmi? Quali sono minimo, media e massimo di charges rispetto ai diversi quartili dei valori di bmi? Nota: è lo stesso esercizio della volta scorsa, ma stavolta da eseguire con il metodo .groupby()

# %%
insurance_df = pd.read_csv("~/Desktop/Python - Epicode/datasets/beginner_datasets/insurance.csv")

# %%
# 1. Dimensioni del dataset
print("Dimensioni:", insurance_df.shape)
# Out:
# Dimensioni: (1338, 7)

# %%
# 2. Anteprima
print("\nPrime righe:")
print(insurance_df.head())
# Out:
# Prime righe:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# 3. Nomi delle colonne
print("\nColonne:")
print(insurance_df.columns)
# Out:
# Colonne:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# 4. Media di charges rispetto a region?
insurance_df.groupby("region")["charges"].mean().round(2)
# Out:
# region
# northeast    13406.38
# northwest    12417.58
# southeast    14735.41
# southwest    12346.94
# Name: charges, dtype: float64

# %%
# 5. Media di charges rispetto a smoker
insurance_df.groupby("smoker")["charges"].mean().round(2)
# Out:
# smoker
# no      8434.27
# yes    32050.23
# Name: charges, dtype: float64

# %%
# 6. Media di charges rispetto a sex
insurance_df.groupby("sex")["charges"].mean().round(2)
# Out:
# sex
# female    12569.58
# male      13956.75
# Name: charges, dtype: float64

# %% [raw]
# La differenza sostanziale la vediamo nella categoria smoker

# %%
# 7. Descrittori statistici di bmi? Quali sono minimo, media e massimo di charges rispetto ai diversi quartili dei valori di bmi? 
insurance_df.describe().round(2)
# Out:
#            age      bmi  children   charges
# count  1338.00  1338.00   1338.00   1338.00
# mean     39.21    30.66      1.09  13270.42
# std      14.05     6.10      1.21  12110.01
# min      18.00    15.96      0.00   1121.87
# 25%      27.00    26.30      0.00   4740.29
# 50%      39.00    30.40      1.00   9382.03
# 75%      51.00    34.69      2.00  16639.91
# max      64.00    53.13      5.00  63770.43

# %%
# 8. Minimo rispetto di quartili di bmi
q1 = insurance_df[insurance_df["bmi"] <= 26.30]
q2 = insurance_df[(insurance_df["bmi"] > 26.30) & (insurance_df["bmi"] <= 30.40)]
q3 = insurance_df[(insurance_df["bmi"] > 30.40) & (insurance_df["bmi"] <= 34.69)]
q4 = insurance_df[insurance_df["bmi"] > 34.69]

print("Primo quartile: ", "Minimo: ", q1["charges"].min())
print("Secondo quartile: ", "Minimo: ", q2["charges"].min())
print("Terzo quartile: ", "Minimo: ", q3["charges"].min())
print("Quarto quartile: ", "Minimo: ", q4["charges"].min())
# Out:
# Primo quartile:  Minimo:  1121.8739
# Secondo quartile:  Minimo:  1131.5066
# Terzo quartile:  Minimo:  1135.9407
# Quarto quartile:  Minimo:  1141.4451

# %%
# 9. Media di charges rispetto ai quartili di bmi
print("Primo quartile: ", "Media: ", q1["charges"].mean().round(2))
print("Secondo quartile: ", "Media: ", q2["charges"].mean().round(2))
print("Terzo quartile: ", "Media: ", q3["charges"].mean().round(2))
print("Quarto quartile: ", "Media: ", q4["charges"].mean().round(2))
# Out:
# Primo quartile:  Media:  10360.66
# Secondo quartile:  Media:  11407.83
# Terzo quartile:  Media:  14358.17
# Quarto quartile:  Media:  16987.94

# %%
#10. Massimo di charges rispetto ai quartili di bmi
print("Primo quartile: ", "Massimo: ", q1["charges"].max())
print("Secondo quartile: ", "Massimo: ", q2["charges"].max())
print("Terzo quartile: ", "Massimo: ", q3["charges"].max())
print("Quarto quartile: ", "Massimo: ", q4["charges"].max())
# Out:
# Primo quartile:  Massimo:  38245.59327
# Secondo quartile:  Massimo:  62592.87309
# Terzo quartile:  Massimo:  60021.39897
# Quarto quartile:  Massimo:  63770.42801

# %% [raw]
# Esercizio 3: Carichiamo in un DataFrame il dataset iris.csv dei beginner_datasets e calcoliamo: • La media della lunghezza dei petali di tutto il dataset • La media della lunghezza dei petali per ogni specie di Iris, utilizzando il metodo .groupby() • Media, minimo e massimo della larghezza dei sepali per ogni specie, utilizzando .groupby() e .agg()

# %%
iris_df = pd.read_csv("~/Desktop/Python - Epicode/datasets/beginner_datasets/iris.csv")
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 1. Media della lunghezza dei petali di tutto il dataset
iris_df["petal_length"].mean().round(2)
# Out:
# 3.76

# %%
# 2. Media della lunghezza dei petali per ogni specie di Iris
iris_df.groupby("species")["petal_length"].mean().round(2)
# Out:
# species
# Iris-setosa        1.46
# Iris-versicolor    4.26
# Iris-virginica     5.55
# Name: petal_length, dtype: float64

# %%
#Media, minimo e massimo della larghezza dei sepali per ogni specie, utilizzando .groupby() e .agg()
iris_df.groupby("species")["sepal_width"].agg(["mean", "min", "max"])
# Out:
#                   mean  min  max
# species
# Iris-setosa      3.418  2.3  4.4
# Iris-versicolor  2.770  2.0  3.4
# Iris-virginica   2.974  2.2  3.8

# %% [raw]
# Esercizio 4: Nei beginner_datasets, il dataset wine.csv contiene delle analisi organolettiche su diverse qualità di vini: • Qual è la media di concentrazione alcolica per ogni qualità? Ci sono differenze? E rispetto alla media totale? • C'è differenza nella concentrazione alcolica per vini bianchi e vini rossi? • Rifacendo le analisi dei due punti precedenti ma per il pH, cambia qualcosa? • E per i solfati?

# %%
wine_df = pd.read_csv("~/Desktop/Python - Epicode/datasets/beginner_datasets/wine.csv")
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# 1. Media di concentrazione alcolica per ogni qualità + media totale
print("Media totale = ", wine_df["alcohol"].mean().round(2)) #media totale
print(wine_df.groupby("quality")["alcohol"].mean().round(2)) #media per qualità

print("Più aumenta la qualità e più la gradazione alcolica aumenta. Inoltre possiamo osservare che la media totale si attesta al livello 6 di qualità")
# Out:
# Media totale =  10.49
# quality
# 3    10.22
# 4    10.18
# 5     9.84
# 6    10.59
# 7    11.39
# 8    11.68
# 9    12.18
# Name: alcohol, dtype: float64
# Più aumenta la qualità e più la gradazione alcolica aumenta. Inoltre possiamo osservare che la media totale si attesta al livello 6 di qualità

# %%
# 2. Concentrazione alcolica per vini bianchi e vini rossi
print(wine_df.groupby("type")["alcohol"].mean().round(2))
print("Tra vino bianco e rosso non c'è quasi alcuna differenza")
# Out:
# type
# red      10.42
# white    10.51
# Name: alcohol, dtype: float64
# Tra vino bianco e rosso non c'è quasi alcuna differenza

# %%
# 3. Rifaccio le analisi dei due punti precedenti ma per il pH 
print("Media totale = ", wine_df["pH"].mean().round(2)) #media totale
print(wine_df.groupby("quality")["pH"].mean().round(2)) #media per qualità

print(wine_df.groupby("type")["pH"].mean().round(2))

print("Per il pH possiamo vedere che i valori sono molto simili tra loro e di conseguenza alla media totale")
# Out:
# Media totale =  3.22
# quality
# 3    3.26
# 4    3.23
# 5    3.21
# 6    3.22
# 7    3.23
# 8    3.22
# 9    3.31
# Name: pH, dtype: float64
# type
# red      3.31
# white    3.19
# Name: pH, dtype: float64
# Per il pH possiamo vedere che i valori sono molto simili tra loro e di conseguenza alla media totale

# %%
# 4. adesso per i solfati
print("Media totale = ", wine_df["sulphates"].mean().round(2)) #media totale
print(wine_df.groupby("quality")["sulphates"].mean().round(2)) #media per qualità

print(wine_df.groupby("type")["sulphates"].mean().round(2))

print("Per il pH possiamo vedere che i valori sono molto simili tra loro e di conseguenza alla media totale")
# Out:
# Media totale =  0.53
# quality
# 3    0.51
# 4    0.51
# 5    0.53
# 6    0.53
# 7    0.55
# 8    0.51
# 9    0.47
# Name: sulphates, dtype: float64
# type
# red      0.66
# white    0.49
# Name: sulphates, dtype: float64
# Per il pH possiamo vedere che i valori sono molto simili tra loro e di conseguenza alla media totale

# %% [raw]
# Esercizio 5 Nei beginner_datasets, il file boston.csv contiene il Boston Housing Dataset, che deriva dalle informazioni raccolte dal Census Service degli Stati Uniti sulle abitazioni nell'area di Boston. Di seguito vengono descritte le colonne del dataset: • CRIM -tasso di criminalità pro capite per città • ZN - proporzione di terreni residenziali suddivisi in zone per lotti superiori a 25.000 piedi quadrati. • INDUS - percentuale di acri di attività commerciali non al dettaglio per città. • CHAS -variabile dummy del fiume Charles (1 se il tratto costeggia il fiume; 0 altrimenti)
# • NOX -concentrazione di ossidi di azoto (parti per 10 milioni). • RM -numero medio di stanze per abitazione • AGE -proporzione di unità abitative occupate da proprietari costruite prima del 1940 • DIS - distanze ponderate da cinque centri occupazionali di Boston • RAD -indice di accessibilità alle autostrade radiali • TAX -aliquota dell'imposta fondiaria sul valore pieno per 10.000 dollari • PTRATIO - rapporto alunni-insegnanti per città • BLACK -la percentuale di neri per città • LSTAT - % di popolazione di condizione più bassa 8 • MEDV -Valore mediano delle case, espresso in migliaia di dollari
# • La media del prezzo delle case cambia a seconda della distanza dal fiume Charles? • Si nota una correlazione tra il tasso di criminalità e il valore delle abitazioni? Come si può spiegare il risultato? • Qual è la media del numero di stanze rispetto al rapporto alunni-insegnanti? E del valore delle case? Appare esserci una qualche correlazione? Come si può spiegare il risultato? • Rispetto all'accessibilità alle autostrade, cambia qualcosa la media delle età delle abitazioni? E del numero di stanze? E delle tasse?

# %%
boston_df = pd.read_csv("~/Desktop/Python - Epicode/datasets/beginner_datasets/boston.csv")
boston_df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#La media del prezzo delle case cambia a seconda della distanza dal fiume Charles?
print(boston_df.groupby("chas")["medv"].mean().round(2))

print("Come possiamo vedere le case vicino al fiume costano di più")
# Out:
# chas
# 0    22.09
# 1    28.44
# Name: medv, dtype: float64
# Come possiamo vedere le case vicino al fiume costano di più

# %%
#Si nota una correlazione tra il tasso di criminalità e il valore delle abitazioni? Come si può spiegare il risultato? 
boston_df["crim"].describe().round(2)
alto_tasso = boston_df["crim"] > 3.61
basso_tasso = boston_df["crim"] < 3.61

print("Prezzo medio con ALTO tasso di criminalità: ", boston_df[alto_tasso]["medv"].mean().round(2))
print("Prezzo medio con BASSO tasso di criminalità: ",boston_df[basso_tasso]["medv"].mean().round(2))
# Out:
# Prezzo medio con ALTO tasso di criminalità:  16.2
# Prezzo medio con BASSO tasso di criminalità:  24.68

# %%
#Qual è la media del numero di stanze rispetto al rapporto alunni-insegnanti? E del valore delle case? Appare esserci una qualche correlazione? Come si può spiegare il risultato?
mediana_ptratio = boston_df["ptratio"].median()
print("Mediana ptratio:", mediana_ptratio)

alto_ptratio = boston_df["ptratio"] > mediana_ptratio  # Molti alunni per insegnante
basso_ptratio = boston_df["ptratio"] <= mediana_ptratio  # Pochi alunni per insegnante

print("Numero medio stanze con ALTO rapporto alunni-insegnanti:", boston_df[alto_ptratio]["rm"].mean().round(2)) # rapporto ptratio-numero stanze
print("Numero medio stanze con BASSO rapporto alunni-insegnanti:", boston_df[basso_ptratio]["rm"].mean().round(2)) # rapporto ptratio-numero stanze

print("Prezzo medio con ALTO rapporto alunni-insegnanti:", boston_df[alto_ptratio]["medv"].mean().round(2)) # rapporto medv-numero stanze
print("Prezzo medio con BASSO rapporto alunni-insegnanti:", boston_df[basso_ptratio]["medv"].mean().round(2)) # rapporto medv-numero stanze

print("--Possiamo vedere che il rapporto alunni-insegnati non influisce sul numero di stanze medio, ma il costo delle case influisce.")
print("Più il rapporto tra alunni e insegnanti è basso, più le case costano--")
# Out:
# Mediana ptratio: 19.05
# Numero medio stanze con ALTO rapporto alunni-insegnanti: 6.06
# Numero medio stanze con BASSO rapporto alunni-insegnanti: 6.51
# Prezzo medio con ALTO rapporto alunni-insegnanti: 18.11
# Prezzo medio con BASSO rapporto alunni-insegnanti: 26.96
# --Possiamo vedere che il rapporto alunni-insegnati non influisce sul numero di stanze medio, ma il costo delle case influisce.
# Più il rapporto tra alunni e insegnanti è basso, più le case costano--

# %%
#Rispetto all'accessibilità alle autostrade, cambia qualcosa la media delle età delle abitazioni? E del numero di stanze? E delle tasse?
mediana_rad = boston_df["rad"].median() #calcolo la mediana "rad"

alto_rad = boston_df["rad"] > mediana_rad #alto indice accessibilità autostrade
basso_rad = boston_df["rad"] <= mediana_rad #basso indice accessibilità autostrade

print("=== ALTA accessibilità autostrade ===")
print("Età media abitazioni:", boston_df[alto_rad]["age"].mean().round(2))
print("Numero medio stanze:", boston_df[alto_rad]["rm"].mean().round(2))  
print("Tasse medie:", boston_df[alto_rad]["tax"].mean().round(2))

print("\n=== BASSA accessibilità autostrade ===")
print("Età media abitazioni:", boston_df[basso_rad]["age"].mean().round(2))
print("Numero medio stanze:", boston_df[basso_rad]["rm"].mean().round(2))
print("Tasse medie:", boston_df[basso_rad]["tax"].mean().round(2))

print("\nPossiamo vedere come l'accessibilità all'autostrada influisce notevolmente sulle tasse medie e in percentuale più bassa sull'età delle abitazioni")
# Out:
# === ALTA accessibilità autostrade ===
# Età media abitazioni: 78.98
# Numero medio stanze: 6.2
# Tasse medie: 552.82
#
# === BASSA accessibilità autostrade ===
# Età media abitazioni: 61.83
# Numero medio stanze: 6.34
# Tasse medie: 314.51
#
# Possiamo vedere come l'accessibilità all'autostrada influisce notevolmente sulle tasse medie e in percentuale più bassa sull'età delle abitazioni

# %% [raw]
# Esercizio 6: Abbiamo un DataFrame di dipendenti: employees_df = pd.DataFrame({ 'employee_id': [101, 102, 103, 104, 105], 'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'], 'department_id': [1, 2, 1, 2, 3] })  e un DataFrame di dipartimenti: departments_df = pd.DataFrame({ 'department_id': [1, 2, 3], 'department_name': ['HR', 'IT', 'Finance'], 'location': ['New York', 'San Francisco', 'Chicago'] }).
# Unire questi DataFrame in base alla colonna comune department_id, in modo da avere nel risultato informazioni sia sui dipendenti che sui dipartimenti, usando la funzione .merge() • Per ogni DataFrame, trasformare la colonna department_id nell'indice, facendo in modo che la modifica sia permanente; poi unire i due dataset mediante il metodo .join() • Ci sono differenze nel risultato? Quali? Perché?

# %%
employees_df = pd.DataFrame ({
    'employee_id' : [101, 102, 103, 104, 105],
    'name' : ['Alice', 'Bob', 'Charlie', 'David', 'Emma'],
    'department_id' : [1, 2, 1, 2, 3]
})

departments_df = pd.DataFrame({
    'department_id' : [1, 2, 3],
    'department_name' : ['HR', 'IT', 'Finance'],
    'location' : ['New York', 'San Francisco', 'Chicago']
})

print("EMPLOYEES:")
print(employees_df)
print("\nDEPARTMENTS:")
print(departments_df)
# Out:
# EMPLOYEES:
#    employee_id     name  department_id
# 0          101    Alice              1
# 1          102      Bob              2
# 2          103  Charlie              1
# 3          104    David              2
# 4          105     Emma              3
#
# DEPARTMENTS:
#    department_id department_name       location
# 0              1              HR       New York
# 1              2              IT  San Francisco
# 2              3         Finance        Chicago

# %%
# 1. Unisco i due df tramite una funzione .merge()
merged_df = pd.merge(employees_df, departments_df, on = "department_id", how = "inner")
merged_df
# Out:
#    employee_id     name  department_id department_name       location
# 0          101    Alice              1              HR       New York
# 1          102      Bob              2              IT  San Francisco
# 2          103  Charlie              1              HR       New York
# 3          104    David              2              IT  San Francisco
# 4          105     Emma              3         Finance        Chicago

# %%
#Setto per entrambi i df 'department_id' come indice, poi unisco i due dataset mediante il metodo .join()
employees_department_id = employees_df.set_index('department_id')
departments_department_id = departments_df.set_index('department_id')

joined_df = employees_department_id.join(departments_department_id, how = 'inner')
joined_df
# Out:
#                employee_id     name department_name       location
# department_id
# 1                      101    Alice              HR       New York
# 2                      102      Bob              IT  San Francisco
# 1                      103  Charlie              HR       New York
# 2                      104    David              IT  San Francisco
# 3                      105     Emma         Finance        Chicago

# %%
#Ci sono differenze nel risultato? Quali? Perché?
print('Si, la prima è department_id nella join è diventata un indice, mentre nella merge è una colonna.\n Per il resto è tutto invariato')
# Out:
# Si, la prima è department_id nella join è diventata un indice, mentre nella merge è una colonna.
#  Per il resto è tutto invariato

# %% [raw]
# Esercizio 6: • Dal database AdventureWorksDW importiamo le tabelle dimemployee e dimemployeesalesterritory come DataFrame • Effettuiamo un join tra i due DataFrame usando le colonne EmployeeKey • Controlliamo la dimensione del DataFrame risultante: è quella attesa? • Importiamo ora la tabella dimsalesterritory ed effettuiamo un join tra questa e il DataFrame risultante della join precedente, usando le colonne SalesTerritoryKey • Su questo DataFrame contare quanti dipendenti ci sono per ogni paese (country) e per ogni regione (region) • Valutiamo la media del BaseRate per ogni paese: ci sono differenze?

# %%
import os
import dotenv
import sqlalchemy
import pandas as pd

dotenv.load_dotenv(dotenv_path="cred.env", override=True)

username = os.getenv("username") 
password = os.getenv("password") 
host = os.getenv("host") 
dbname = os.getenv("dbname") 

connection_string = "mysql+pymysql://"+username+":"+password+"@"+host+"/"+dbname 

db_engine = sqlalchemy.create_engine(connection_string)

# %%
# 1. Importo la prima tabella
dimemployee = pd.read_sql("SELECT * FROM dimemployee", db_engine)
dimemployee.sample(10)
# Out:
#      EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 142          143              112.0                       184188301
# 10            11                3.0                       695256908
# 211          212               20.0                        63179277
# 135          136              177.0                       363996959
# 93            94              147.0                       212801092
# 256          257               43.0                       343861179
# 129          130               92.0                       242381745
# 262          263               51.0                        28414965
# 101          102               89.0                       830150469
# 145          146              138.0                       764853868
#
#      ParentEmployeeNationalIDAlternateKey FirstName        LastName  \
# 142                           295847284.0     Laura          Norman
# 10                            509647174.0      Gail        Erickson
# ...

# %%
# 2. Importo la seconda tabella
dimemployeesalesterritory = pd.read_sql("SELECT * FROM dimemployeesalesterritory", db_engine)
dimemployeesalesterritory.sample(10)
# Out:
#     EmployeeKey  SalesTerritoryKey
# 4           293                  1
# 34          294                  9
# 9           277                  3
# 27          290                  7
# 24          284                  6
# 30          277                  8
# 17          287                  4
# 26          277                  7
# 6           277                  2
# 18          272                  5

# %%
# 3. Effettuo un join tra i due DataFrame usando le colonne EmployeeKey  
first_merge = dimemployee.merge(dimemployeesalesterritory, on='EmployeeKey', how = 'inner')
print(first_merge.shape)

print('\nSi, il risultato è quello atteso.')
# Out:
# (39, 29)
#
# Si, il risultato è quello atteso.

# %%
# 4. Importo ora la tabella dimsalesterritory 
dimsalesterritory = pd.read_sql('SELECT * FROM dimsalesterritory', db_engine)
dimsalesterritory
# Out:
#     SalesTerritoryKey  SalesTerritoryAlternateKey SalesTerritoryRegion  \
# 0                   1                           1            Northwest
# 1                   2                           2            Northeast
# 2                   3                           3              Central
# 3                   4                           4            Southwest
# 4                   5                           5            Southeast
# 5                   6                           6               Canada
# 6                   7                           7               France
# 7                   8                           8              Germany
# 8                   9                           9            Australia
# 9                  10                          10       United Kingdom
# 10                 11                           0         Corporate HQ
#
#    SalesTerritoryCountry SalesTerritoryGroup  \
# 0          United States       North America
# ...

# %%
# 5. Effettuo un join tra dimsalesterritory e first_merge, usando le colonne SalesTerritoryKey
final_result = first_merge.merge(dimsalesterritory, on = 'SalesTerritoryKey', how = 'inner')
final_result.sample(10)
# Out:
#     EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 38          296              294.0                       758596752
# 33          291              290.0                       668991357
# 18          281              272.0                       841560125
# 4           272              277.0                       502097814
# 27          288              272.0                       399771412
# 26          287              272.0                       139397894
# 25          286              272.0                        61161660
# 20          282              272.0                       191644724
# 30          290              277.0                       982310417
# 35          293              272.0                        90836195
#
#     ParentEmployeeNationalIDAlternateKey FirstName      LastName MiddleName  \
# 38                           481044938.0      Lynn      Tsoflias          N
# ...

# %%
# 6. Conto quanti dipendenti ci sono per ogni paese (country) e per ogni regione (region)
final_result.groupby(['SalesTerritoryCountry', 'SalesTerritoryRegion'])['EmployeeKey'].count()
# Out:
# SalesTerritoryCountry  SalesTerritoryRegion
# Australia              Australia               3
# Canada                 Canada                  4
# France                 France                  4
# Germany                Germany                 3
# United Kingdom         United Kingdom          3
# United States          Central                 5
#                        Northeast               3
#                        Northwest               5
#                        Southeast               4
#                        Southwest               5
# Name: EmployeeKey, dtype: int64

# %%
# 7. Valuto la media del BaseRate per ogni paese
final_result.groupby('SalesTerritoryCountry')['BaseRate'].mean().round(2)
# Out:
# SalesTerritoryCountry
# Australia         47.76
# Canada            41.59
# France            41.59
# Germany           47.76
# United Kingdom    47.76
# United States     39.91
# Name: BaseRate, dtype: float64
